# %%
import numpy as np

# %% [markdown]
# ### 1st Example

# %%
observ = np.array([22, 17, 20, 26, 22, 13])
expact = np.array([20, 20, 20, 20, 20, 20])

# %% [markdown]
# ### Chi squared Formula

# %%
np.sum(np.square(observ-expact)/expact)
# Out:
# 5.1000000000000005

# %% [markdown]
# ## 2nd Exmaple Chi Sqaured Test

# %%
import numpy as np

# %%
row1 = np.array([40, 45, 25, 10])
row2 = np.array([35, 30, 20, 30])

# %%
sum_r1 = np.sum(row1)
sum_r2 = np.sum(row2)
sum_row = np.array([sum_r1, sum_r2])
sum_row
# Out:
# array([120, 115])

# %%
sum_cal = row1 + row2
sum_cal
# Out:
# array([75, 75, 45, 40])

# %%
exp = []
for i in sum_row :
    for j in sum_cal :
        value = (i*j)/235
        exp.append(value)

# %%
obj = np.array([40,45,25,10,35,30,20,30])

# %% [markdown]
# ### Chi squared Formula

# %%
np.sum((np.square(obj - exp))/ exp)
# Out:
# 13.788747987117553
