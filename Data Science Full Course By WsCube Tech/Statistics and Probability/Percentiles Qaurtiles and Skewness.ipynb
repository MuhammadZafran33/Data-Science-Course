# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Mall_customers.csv")

# %%
dataset.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
dataset.dropna()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
dataset["Age"]
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
np.percentile(dataset["Age"], 28), np.percentile(dataset["Age"], 50)
# Out:
# (30.0, 36.0)

# %%
np.percentile(dataset["Age"], 18), np.percentile(dataset["Age"], 99)
# Out:
# (25.0, 69.00999999999999)

# %%
np.percentile(dataset["Age"], 0)
# Out:
# 18.0

# %%
 np.percentile(dataset["Age"], 0), dataset["Age"].min()
# Out:
# (18.0, 18)

# %%
np.percentile(dataset["Age"], 50), dataset["Age"].median()
# Out:
# (36.0, 36.0)

# %%
np.percentile(dataset["Age"], 100), dataset["Age"].max()
# Out:
# (70.0, 70)

# %%
dataset.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
sns.boxplot(x="Age", data=dataset)
plt.show()

# %%
sns.boxplot(x="Annual Income (k$)", data=dataset)
plt.show()

# %% [markdown]
# # Skewness in Datasets

# %%
sns.histplot(x="Age", data=dataset)
plt.show()

# %%
dataset["Age"].skew()
# Out:
# 0.48556885096681657

# %%
data = np.random.normal(0,20,20)
data
# Out:
# array([ -7.379614  ,  17.63984476, -17.40712521, -10.83003391,
#        -18.61030538, -18.41176312,  -8.59459478, -13.7507817 ,
#         14.20570483,  -9.00314197, -29.80397069, -17.02192412,
#         47.38900809, -27.47335604,   7.52543899,   6.71814732,
#        -34.08265346,  23.10033559,  25.48521475,  -2.50279854])

# %%
df = pd.DataFrame({"x": data})
df
df["x"].skew()
# Out:
# 0.4414453763873652

# %%
sns.histplot(x="x", data=df, bins="auto")
plt.show()
