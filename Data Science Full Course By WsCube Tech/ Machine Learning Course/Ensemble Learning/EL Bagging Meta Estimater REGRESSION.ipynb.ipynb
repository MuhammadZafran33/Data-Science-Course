# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Student_performance.csv')

# %%
dataset.head(4)
# Out:
#    id  study_hours  attendance_percent  sleep_hours  previous_score  \
# 0   1          2.0                60.5          5.5              45
# 1   2          2.5                62.0          5.8              48
# 2   3          3.0                65.0          6.0              50
# 3   4          3.2                66.5          6.2              52
#
#    final_score
# 0           50
# 1           52
# 2           55
# 3           57

# %%
x = dataset.iloc[:,:-1]
y = dataset["final_score"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
bg = BaggingRegressor(estimator=DecisionTreeRegressor(), n_estimators=40)
bg.fit(x_train,y_train)
bg.score(x_train,y_train)*100, bg.score(x_test,y_test)*100
# Out:
# (99.91328370823702, 99.40472960586617)

# %%
rf = RandomForestRegressor(n_estimators=40)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)*100, rf.score(x_test,y_test)*100
# Out:
# (99.92340152541165, 99.48439046746105)
