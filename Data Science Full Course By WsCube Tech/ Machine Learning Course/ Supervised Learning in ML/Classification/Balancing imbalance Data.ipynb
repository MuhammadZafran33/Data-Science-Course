# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
dataset=pd.read_csv('/content/online_gaming.csv')
dataset.head(5)
# Out:
#    PlayerID  Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other  Strategy      16.271119                0
# 1      9001   29  Female      USA  Strategy       5.525961                0
# 2      9002   22  Female      USA    Sports       8.223755                0
# 3      9003   35    Male      USA    Action       5.265351                1
# 4      9004   33    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked EngagementLevel
# ...

# %%
dataset["InGamePurchases"].value_counts()
# Out:
# InGamePurchases
# 0    31993
# 1     8041
# Name: count, dtype: int64

# %%
x= dataset.iloc[:,6:-6].columns
y = dataset["InGamePurchases"]

# %%
pip install imblearn

# %% [markdown]
# Now that `imblearn` is installed, we can apply a balancing technique to our training data. `RandomOverSampler` is a common choice for oversampling the minority class.

# %%
from imblearn.over_sampling import RandomOverSampler

# Instantiate RandomOverSampler
ros = RandomOverSampler(random_state=42)

# Resample the training data
x_train_resampled, y_train_resampled = ros.fit_resample(x_train, y_train)

print("Original training target distribution:\n", y_train.value_counts())
print("\nResampled training target distribution:\n", y_train_resampled.value_counts())
# Out:
# Original training target distribution:
#  InGamePurchases
# 0    25616
# 1     6411
# Name: count, dtype: int64
#
# Resampled training target distribution:
#  InGamePurchases
# 0    25616
# 1    25616
# Name: count, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   40034 non-null  int64
#  1   Age                        40034 non-null  int64
#  2   Gender                     40034 non-null  object
#  3   Location                   40034 non-null  object
#  4   GameGenre                  40034 non-null  object
#  5   PlayTimeHours              40034 non-null  float64
#  6   InGamePurchases            40034 non-null  int64
#  7   GameDifficulty             40034 non-null  object
#  8   SessionsPerWeek            40034 non-null  int64
#  9   AvgSessionDurationMinutes  40034 non-null  int64
#  10  PlayerLevel                40034 non-null  int64
#  11  AchievementsUnlocked       40034 non-null  int64
#  12  EngagementLevel            40034 non-null  object
# ...

# %%
x = dataset.drop(['PlayerID', 'InGamePurchases'], axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=42, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train_encoded = pd.get_dummies(x_train, columns=['Gender', 'Location', 'GameGenre', 'GameDifficulty', 'EngagementLevel'], drop_first=True)
x_test_encoded = pd.get_dummies(x_test, columns=['Gender', 'Location', 'GameGenre', 'GameDifficulty', 'EngagementLevel'], drop_first=True)

lr = LogisticRegression(max_iter=1000) # Increased max_iter for convergence with more features
lr.fit(x_train_encoded, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lr.score(x_test_encoded, y_test)
# Out:
# 0.7964281253902835

# %%
lr.predict(x_test_encoded)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
