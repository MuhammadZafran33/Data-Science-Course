# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset= pd.read_csv("creditcard.csv")
dataset.head(5)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0   89630.0  0.030601  0.859108  0.290804 -0.591915  0.441892 -1.033405
# 1   33404.0  1.042874  0.348936 -0.207597  2.215841  0.991928  1.349503
# 2   57910.0 -1.549217  0.444995  1.953795  0.767481  1.249854 -0.439201
# 3  133413.0 -0.322340  0.969558  0.462259 -0.100560 -0.187871 -1.069206
# 4  171524.0  1.990957 -1.984952 -1.014321 -1.265569 -1.371786  0.034195
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  1.016281 -0.190080 -0.066897  ... -0.251454 -0.537176  0.081516 -0.016869
# 1  0.100767  0.451493 -0.739607  ...  0.064860  0.193583 -0.007651 -1.379281
# 2  0.843048  0.145210 -1.561334  ...  0.226098  0.136749 -0.178771 -0.013354
# 3  0.454631  0.211302 -0.162835  ...  0.164689  0.497732 -0.038204  0.420742
# 4 -1.117904  0.061933 -0.828024  ... -0.416109 -0.844353  0.244993  0.716250
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x="Time", y="V2", data=dataset, hue="Amount")
plt.legend(loc=1)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["V2"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 lr= LogisticRegression()
# ----> 2 lr.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1191 X, y = validate_data(
#    1192     self,
#    1193     X,
#    (...)
#    1198     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1199 )
# ...

# %%
# Option 1: If you need classification, convert continuous values to discrete classes
from sklearn.preprocessing import KBinsDiscretizer
import numpy as np

# Convert pandas Series to numpy array before reshaping
# The error occurs because pandas Series doesn't have reshape method
y_train_array = np.array(y_train)  # Convert Series to numpy array
y_train_discrete = KBinsDiscretizer(n_bins=2, encode='ordinal', strategy='quantile').fit_transform(
    y_train_array.reshape(-1, 1)).flatten()

# Now use LogisticRegression with discrete classes
lr = LogisticRegression()
lr.fit(x_train, y_train_discrete)

# Option 2: If you need regression with continuous target values, use a regression model instead
from sklearn.linear_model import LinearRegression

# Use a regression model for continuous target values
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# C:\Users\pts\anaconda3\Lib\site-packages\sklearn\preprocessing\_discretization.py:304: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# C:\Users\pts\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(), clf=lr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 plot_decision_regions(x.to_numpy(),y.to_numpy(), clf=lr)
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:161, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#      50 def plot_decision_regions(
#      51     X,
#      52     y,
#    (...)
#      72     n_jobs=None,
#      73 ):
#      74     """Plot decision regions of a classifier.
#      75
#      76     Please note that this functions assumes that class labels are
#    (...)
#     158
#     159     """
# --> 161     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     162     dim = X.shape[1]
# ...

# %%
# Convert y to integer type before passing to plot_decision_regions
plot_decision_regions(x.to_numpy(), y.to_numpy().astype(np.int_), clf=lr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Convert y to integer type before passing to plot_decision_regions
# ----> 2 plot_decision_regions(x.to_numpy(), y.to_numpy().astype(np.int_), clf=lr)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:204, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     202 if dim > 2:
#     203     if filler_feature_values is None:
# --> 204         raise ValueError(
#     205             "Filler values must be provided when "
#     206             "X has more than 2 training features."
#     207         )
#     209     if filler_feature_ranges is not None:
# ...
