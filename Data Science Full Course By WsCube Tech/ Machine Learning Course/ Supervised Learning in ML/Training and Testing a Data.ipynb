# %%
import pandas as pd

# %%
dataset = pd.read_csv("housing_ocean.csv")

# %%
dataset.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.shape
# Out:
# (20640, 10)

# %%
input_data = dataset.iloc[:,:-1]  # This line is correct, selecting all rows and all columns except the last one

# Option 1: Using loc with column name
output_data = dataset.loc[:, "median_house_value"]

# Option 2: Direct column access (simpler and more common)
output_data = dataset["median_house_value"]

# Option 3: If you want to use iloc, you need the column index
# Assuming "median_house_value" is the last column:
# output_data = dataset.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(input_data,output_data, test_size=0.25)

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1530     -122.06     37.88                34.0       4781.0           703.0
# 15191    -117.05     33.02                18.0        917.0           121.0
# 11051    -117.86     33.79                31.0       3523.0           922.0
# 916      -121.97     37.51                25.0       3333.0           511.0
# 17780    -121.84     37.38                33.0        835.0           181.0
# ...          ...       ...                 ...          ...             ...
# 3015     -119.16     34.95                14.0       4054.0           787.0
# 3417     -118.42     34.28                29.0       1271.0           272.0
# 20416    -118.85     34.20                28.0       2040.0           297.0
# 12361    -116.48     33.84                 5.0       5480.0          1371.0
# 15802    -122.44     37.75                28.0       4930.0          1381.0
#
# ...

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1884     -119.99     38.93                23.0       1882.0           414.0
# 125      -122.22     37.85                28.0       5287.0          1048.0
# 9681     -118.97     37.64                14.0       2284.0           622.0
# 6447     -118.05     34.11                42.0       3677.0           627.0
# 15008    -117.02     32.76                40.0       2523.0           488.0
# ...          ...       ...                 ...          ...             ...
# 15672    -122.44     37.80                52.0       3161.0           472.0
# 2499     -120.39     36.78                11.0       1947.0           488.0
# 2309     -119.74     36.83                14.0       4675.0           829.0
# 18436    -121.84     37.25                17.0       2363.0           473.0
# 6166     -117.93     34.09                34.0       2192.0           431.0
#
# ...

# %%
y_train
# Out:
# 1884     141900.0
# 125      337300.0
# 9681      87500.0
# 6447     426500.0
# 15008    185700.0
#            ...
# 15672    500001.0
# 2499      55200.0
# 2309     108200.0
# 18436    141600.0
# 6166     163900.0
# Name: median_house_value, Length: 15480, dtype: float64

# %%
y_test
# Out:
# 1530     340900.0
# 15191    260100.0
# 11051    146400.0
# 916      258300.0
# 17780    195800.0
#            ...
# 3015     148200.0
# 3417     150000.0
# 20416    323700.0
# 12361    137500.0
# 15802    316200.0
# Name: median_house_value, Length: 5160, dtype: float64

# %%
x_test.shape , y_test.shape
# Out:
# ((5160, 9), (5160,))

# %%
y_train.shape , x_train.shape
# Out:
# ((15480,), (15480, 9))
