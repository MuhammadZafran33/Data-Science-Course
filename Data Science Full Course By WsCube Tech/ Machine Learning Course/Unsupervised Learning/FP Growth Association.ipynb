# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GroceriesItmes.csv')
dataset.head(5)
# Out:
#    transaction_id  item1   item2   item3      item4   item5  item6  item7  \
# 0               1   milk   bread  butter       eggs  cheese    NaN    NaN
# 1               2   milk   bread    eggs     cheese     NaN    NaN    NaN
# 2               3  bread  butter  tomato      onion  potato    NaN    NaN
# 3               4   milk  banana   apple  chocolate     NaN    NaN    NaN
# 4               5   milk   bread  butter  chocolate    soda    NaN    NaN
#
#    item8  item9  item10
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN

# %%
dataset["item1"][0]
# Out:
# 'milk'

# %%
for i in range(0,dataset.shape[0]):
    for j in dataset.columns:
      print(dataset)
# Out:
# Streaming output truncated to the last 5000 lines.
# 197    NaN    NaN    NaN     NaN
# 198    NaN    NaN    NaN     NaN
# 199    NaN    NaN    NaN     NaN
#
# [200 rows x 11 columns]
#      transaction_id   item1    item2      item3      item4   item5  item6  \
# 0                 1    milk    bread     butter       eggs  cheese    NaN
# 1                 2    milk    bread       eggs     cheese     NaN    NaN
# 2                 3   bread   butter     tomato      onion  potato    NaN
# 3                 4    milk   banana      apple  chocolate     NaN    NaN
# 4                 5    milk    bread     butter  chocolate    soda    NaN
# ..              ...     ...      ...        ...        ...     ...    ...
# 195             215    milk    bread     butter        NaN     NaN    NaN
# 196             216  banana    apple  chocolate        NaN     NaN    NaN
# 197             217    rice  chicken      onion     tomato     NaN    NaN
# ...

# %%
market = []
for i in range(0,dataset.shape[0]):
  cus = []
  for j in dataset.columns:
      if type(dataset[j][i]) == str:
        cus.append(dataset[j][i])
        market.append(cus)

# %%
l = []
for i in market:
  for j in i:
    l.append(j)

# %%
import collections

# %%
p = collections.Counter(l)

# %%
p.keys()
# Out:
# dict_keys(['milk', 'bread', 'butter', 'eggs', 'cheese', 'tomato', 'onion', 'potato', 'banana', 'apple', 'chocolate', 'soda', 'rice', 'chicken', 'salt', 'coffee', 'yogurt', 'tea', 'beef', 'sugar'])

# %%
p.values()
# Out:
# dict_values([464, 376, 256, 184, 168, 216, 248, 104, 184, 184, 184, 96, 176, 136, 112, 128, 64, 64, 40, 96])

# %%
d = {"Item Name": p.keys(),"values": p.values()}

# %%
pd.DataFrame(d).sort_values(by="values",ascending=False)
# Out:
#     Item Name  values
# 0        milk     464
# 1       bread     376
# 2      butter     256
# 6       onion     248
# 5      tomato     216
# 3        eggs     184
# 9       apple     184
# 8      banana     184
# 10  chocolate     184
# 12       rice     176
# 4      cheese     168
# 13    chicken     136
# 15     coffee     128
# 14       salt     112
# 7      potato     104
# 11       soda      96
# 19      sugar      96
# 16     yogurt      64
# 17        tea      64
# 18       beef      40

# %%
pd.set_option("display.max_rows", 200)

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()

# %%
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
tr.transform(market)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ...,  True, False, False]])

# %%
df  = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
df
# Out:
#      apple  banana   beef  bread  butter  cheese  chicken  chocolate  coffee  \
# 0    False   False  False   True    True    True    False      False   False
# 1    False   False  False   True    True    True    False      False   False
# 2    False   False  False   True    True    True    False      False   False
# 3    False   False  False   True    True    True    False      False   False
# 4    False   False  False   True    True    True    False      False   False
# ..     ...     ...    ...    ...     ...     ...      ...        ...     ...
# 819  False   False  False   True   False    True    False      False   False
# 820  False   False  False  False   False   False    False      False    True
# 821  False   False  False  False   False   False    False      False    True
# 822  False   False  False  False   False   False    False      False    True
# 823  False   False  False  False   False   False    False      False    True
#
# ...

# %%
from mlxtend.frequent_patterns import apriori
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
apriori(df,min_support=0.09, use_colnames=True, max_len=3).sort_values(by=["support"])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
from mlxtend.frequent_patterns import fpgrowth
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
fpgrowth(df,min_support=0.09, use_colnames=True, max_len=3).sort_values(by=["support"])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
