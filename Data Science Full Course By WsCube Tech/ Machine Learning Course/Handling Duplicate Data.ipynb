# %%
import pandas as pd

# %%
data = {"Names":["a","b","c","d","a","b","c","a"], "eng":[2,3,4,5,2,3,7,2], "math":[6,7,8,9,6,7,8,6]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Names  eng  math
# 0     a    2     6
# 1     b    3     7
# 2     c    4     8
# 3     d    5     9
# 4     a    2     6
# 5     b    3     7
# 6     c    7     8
# 7     a    2     6

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
# df["duplicated"] = df.duplicated()

# %%
# df

# %%
df.drop_duplicates()
# Out:
#   Names  eng  math
# 0     a    2     6
# 1     b    3     7
# 2     c    4     8
# 3     d    5     9
# 6     c    7     8

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   Names  eng  math
# 0     a    2     6
# 1     b    3     7
# 2     c    4     8
# 3     d    5     9
# 6     c    7     8

# %%
dataset = pd.read_csv("Hitters.csv")
dataset.head(3)
# Out:
#        Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  \
# 0  -Andy Allanson    293    66      1    30   29     14      1     293     66
# 1     -Alan Ashby    315    81      7    24   38     39     14    3449    835
# 2    -Alvin Davis    479   130     18    66   72     76      3    1624    457
#
#    ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  Salary  \
# 0  ...     30    29      14       A        E     446       33      20     NaN
# 1  ...    321   414     375       N        W     632       43      10   475.0
# 2  ...    224   266     263       A        W     880       82      14   480.0
#
#    NewLeague
# 0          A
# 1          N
# 2          A
#
# [3 rows x 21 columns]

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# Length: 322, dtype: bool

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.shape
# Out:
# (322, 21)

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (322, 21)

# %%
dataset1 = pd.read_csv("diabetes_dataset.csv")
dataset1.head(3)
# Out:
#    PatientID  Age  Gender        BMI  BloodPressure  Insulin  Glucose  \
# 0          1   52       0  30.239636            149      113      115
# 1          2   53       1  30.932781             71       39      104
# 2          3   21       0  45.092714            161       67      151
#
#    DiabetesPedigreeFunction  Outcome
# 0                  0.312886        1
# 1                  0.389526        0
# 2                  1.205869        0

# %%
dataset.duplicated().sum()
# Out:
# 0
